# %% [markdown]
# В заданиях, кажется, ошибка, поскольку второе задание - это просто уточнение к первому

# %%
def sum_of_two(nums, target):
  for i in range(0, len(nums) - 1):
    for j in range(i+1, len(nums)):
      if nums[i] + nums[j] == target:
        return [i, j]
